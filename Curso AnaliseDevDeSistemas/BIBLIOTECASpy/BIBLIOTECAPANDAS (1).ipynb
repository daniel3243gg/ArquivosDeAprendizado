# %%
import pandas as pd

venda = {'data':['14/10/2023', '15/10/2024'],
         'produto':['feijao', 'arroz'],
         'valor': [700,200],
         'qntd': [200,40]}
vendas_df = pd.DataFrame(venda)
display(vendas_df)
# Out:
#          data produto  valor  qntd
# 0  14/10/2023  feijao    700   200
# 1  15/10/2024   arroz    200    40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7776bc54cb14> in <cell line: 12>()
#      10
#      11 ##CRIANDO TABELAS A PARTIDAR DE ARQUIVOS EXTERNOS
# ---> 12 shop_df= pd.read_csv(shope.xls)
#      13 display(shop_df)
#
# NameError: name 'shope' is not defined

# %%
##CRIANDO TABELAS A PARTIDAR DE ARQUIVOS EXTERNOS

spotify_df = pd.read_csv('spotify.csv',encoding='latin1')
display(spotify_df)#printando o arquivo
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
display(spotify_df.head(10))#printando e selecionando quais linhas deseja vê
print(spotify_df.shape)#printa quantas colunas é linhas
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
#manipulando colunas e linhas

cantores = spotify_df[['artist(s)_name', 'released_year']]#selecionando as colunas que deseja colocando uma lista[] dentro do indice
display(cantores)
# Out:
#          artist(s)_name  released_year
# 0      Latto, Jung Kook           2023
# 1           Myke Towers           2023
# 2        Olivia Rodrigo           2023
# 3          Taylor Swift           2019
# 4             Bad Bunny           2023
# ..                  ...            ...
# 948        Selena Gomez           2022
# 949        Taylor Swift           2022
# 950  Feid, Paulo Londra           2022
# 951  Feid, Sech, Jhayco           2022
# 952           Burna Boy           2022
#
# [953 rows x 2 columns]

# %%
display(spotify_df.loc[60:61]) # pegando as linhas que desejo com loc
display(spotify_df.loc[spotify_df['artist(s)_name']== 'Taylor Swift' ])#passei uma condiçao para dentro do loc assim exigindo oque tenho interesse
display(spotify_df.loc[spotify_df['artist(s)_name']== 'Taylor Swift' , ['track_name', 'streams']])#passei parametros de linhas, colunas para dentro do loc
# Out:
#                                             track_name     streams
# 3                                         Cruel Summer   800840817
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...    52135248
# 33                                           Anti-Hero   999748277
# 37                                         Blank Space  1355959075
# 38                                               Style   786181836
# 59                                            cardigan   812019557
# 66                                               Karma   404562836
# 69                        Enchanted (Taylor's Version)    39578178
# 83                 Back To December (Taylor's Version)    39228929
# 93                                    Donï¿½ï¿½ï¿½t Bl   685032533
# 100                                              Lover   882831184
# 113                            Mine (Taylor's Version)    36912123
# 119                                             august   607123776
# ...

# %%
#CRIANDO COLUNAS:
spotify_df['CantouOuNao'] = spotify_df['artist_count'].apply(lambda x: 'cantou' if x > 1 else 'nao cantou')#coluna criada a partir de outra coluna
display(spotify_df)

spotify_df.loc[:, 'nulo'] = 0 #criar sempre com o loc é mais seguro, : significa que é para pegar todas linhas
display(spotify_df)
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
#deletando colunas ou linhas
spotify_df = spotify_df.drop("nulo", axis=1)#excluindo a coluna desejado, axis=1 fala que desejo excluir uma coluna
spotify_df = spotify_df.drop(0, axis=0)#excluindo a linha desejado, axis=0 fala que desejo excluir uma linha

display(spotify_df)
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 1                         LALA         Myke Towers             1
# 2                      vampire      Olivia Rodrigo             1
# 3                 Cruel Summer        Taylor Swift             1
# 4               WHERE SHE GOES           Bad Bunny             1
# 5                     Sprinter   Dave, Central Cee             2
# ..                         ...                 ...           ...
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 1             2023               3            23                  1474
# ...

# %%
#DELETAS LINHAS É COLUNAS TOLTAMENTE VAZIAS
spotify_df = spotify_df.dropna(how='all', axis= 1)#how é qual coluna axis define si é coluna ou linha

#DELETAR LINHAS E COLUNAS COM ALGUM VALOR VAZIO
sporify_df = spotify_df.dropna()

#DESCUBRI A MEDIA DE LINHAS OU COLUNAS
media_streams = spotify_df['released_day'].mean()
print(int(media_streams))

#PREENCHA COM O VALOR DE CIMA
spotify_df.ffill()


#mesclar dataframes
dataframe1 = dataframe1.merge(dataframe2)
# Out:
# 13
